# %%
# %pip install langchain-openai python-dotenv
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-0.3.29-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 4.4 MB/s eta 0:00:00
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Collecting tiktoken<1,>=0.7
#   Downloading tiktoken-0.11.0-cp310-cp310-macosx_11_0_arm64.whl (999 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 999.2/999.2 kB 22.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting langchain-core<1.0.0,>=0.3.74
#   Downloading langchain_core-0.3.74-py3-none-any.whl (443 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.5/443.5 kB 12.6 MB/s eta 0:00:00m eta 0:00:01
# Collecting openai<2.0.0,>=1.86.0
#   Downloading openai-1.99.9-py3-none-any.whl (786 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 786.8/786.8 kB 30.8 MB/s eta 0:00:00
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0
#   Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/jaeminjeong/.pyenv/versions/3.10.18/envs/inflearn-llm-application/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (4.14.1)
# Collecting pydantic>=2.7.4
#   Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.8/444.8 kB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=23.2 in /Users/jaeminjeong/.pyenv/versions/3.10.18/envs/inflearn-llm-application/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (25.0)
# Collecting PyYAML>=5.3
#   Downloading PyYAML-6.0.2-cp310-cp310-macosx_11_0_arm64.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.8/171.8 kB 18.8 MB/s eta 0:00:00
# Collecting langsmith>=0.3.45
#   Downloading langsmith-0.4.13-py3-none-any.whl (372 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 372.7/372.7 kB 32.1 MB/s eta 0:00:00
# Collecting jsonpatch<2.0,>=1.33
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting sniffio
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting tqdm>4
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 9.1 MB/s eta 0:00:00
# Collecting anyio<5,>=3.5.0
#   Downloading anyio-4.10.0-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.2/107.2 kB 11.0 MB/s eta 0:00:00
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting httpx<1,>=0.23.0
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 9.8 MB/s eta 0:00:00
# Collecting jiter<1,>=0.4.0
#   Downloading jiter-0.10.0-cp310-cp310-macosx_11_0_arm64.whl (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.8/322.8 kB 18.5 MB/s eta 0:00:00
# Collecting regex>=2022.1.18
#   Downloading regex-2025.7.34-cp310-cp310-macosx_11_0_arm64.whl (285 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.9/285.9 kB 20.6 MB/s eta 0:00:00
# Collecting requests>=2.26.0
#   Downloading requests-2.32.4-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 kB 8.6 MB/s eta 0:00:00
# Collecting idna>=2.8
#   Downloading idna-3.10-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/jaeminjeong/.pyenv/versions/3.10.18/envs/inflearn-llm-application/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.86.0->langchain-openai) (1.3.0)
# Collecting certifi
#   Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 15.0 MB/s eta 0:00:00
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 9.9 MB/s eta 0:00:00
# Collecting h11>=0.16
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting orjson>=3.9.14
#   Downloading orjson-3.11.1-cp310-cp310-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.3/241.3 kB 25.7 MB/s eta 0:00:00
# Collecting zstandard>=0.23.0
#   Downloading zstandard-0.23.0-cp310-cp310-macosx_11_0_arm64.whl (633 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 633.7/633.7 kB 28.2 MB/s eta 0:00:00
# Collecting requests-toolbelt>=1.0.0
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.6 MB/s eta 0:00:00
# Collecting pydantic-core==2.33.2
#   Downloading pydantic_core-2.33.2-cp310-cp310-macosx_11_0_arm64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 41.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting typing-inspection>=0.4.0
#   Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.3-cp310-cp310-macosx_10_9_universal2.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.7/207.7 kB 16.2 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 kB 15.9 MB/s eta 0:00:00
# Installing collected packages: zstandard, urllib3, typing-inspection, tqdm, tenacity, sniffio, regex, PyYAML, python-dotenv, pydantic-core, orjson, jsonpointer, jiter, idna, h11, distro, charset_normalizer, certifi, annotated-types, requests, pydantic, jsonpatch, httpcore, anyio, tiktoken, requests-toolbelt, httpx, openai, langsmith, langchain-core, langchain-openai
# Successfully installed PyYAML-6.0.2 annotated-types-0.7.0 anyio-4.10.0 certifi-2025.8.3 charset_normalizer-3.4.3 distro-1.9.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.10 jiter-0.10.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-core-0.3.74 langchain-openai-0.3.29 langsmith-0.4.13 openai-1.99.9 orjson-3.11.1 pydantic-2.11.7 pydantic-core-2.33.2 python-dotenv-1.1.1 regex-2025.7.34 requests-2.32.4 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.2 tiktoken-0.11.0 tqdm-4.67.1 typing-inspection-0.4.1 urllib3-2.5.0 zstandard-0.23.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()

# %%
llm.invoke("인프런에는 어떤 강의가 있나요?")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 llm.invoke("인프런에는 어떤 강의가 있나요?")
#
# File ~/.pyenv/versions/3.10.18/envs/inflearn-llm-application/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:383, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     371 @override
#     372 def invoke(
#     373     self,
#    (...)
#     378     **kwargs: Any,
#     379 ) -> BaseMessage:
#     380     config = ensure_config(config)
#     381     return cast(
#     382         "ChatGeneration",
# --> 383         self.generate_prompt(
#     384             [self._convert_input(input)],
#     385             stop=stop,
#     386             callbacks=config.get("callbacks"),
#     387             tags=config.get("tags"),
#     388             metadata=config.get("metadata"),
#     389             run_name=config.get("run_name"),
#     390             run_id=config.pop("run_id", None),
#     391             **kwargs,
#     392         ).generations[0][0],
#     393     ).message
#
# File ~/.pyenv/versions/3.10.18/envs/inflearn-llm-application/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1006, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     997 @override
#     998 def generate_prompt(
#     999     self,
#    (...)
#    1003     **kwargs: Any,
#    1004 ) -> LLMResult:
#    1005     prompt_messages = [p.to_messages() for p in prompts]
# -> 1006     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/.pyenv/versions/3.10.18/envs/inflearn-llm-application/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:825, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     822 for i, m in enumerate(input_messages):
#     823     try:
#     824         results.append(
# --> 825             self._generate_with_cache(
#     826                 m,
#     827                 stop=stop,
#     828                 run_manager=run_managers[i] if run_managers else None,
#     829                 **kwargs,
#     830             )
#     831         )
#     832     except BaseException as e:
#     833         if run_managers:
#
# File ~/.pyenv/versions/3.10.18/envs/inflearn-llm-application/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1072, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1070     result = generate_from_stream(iter(chunks))
#    1071 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1072     result = self._generate(
#    1073         messages, stop=stop, run_manager=run_manager, **kwargs
#    1074     )
#    1075 else:
#    1076     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/.pyenv/versions/3.10.18/envs/inflearn-llm-application/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1177, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1175     generation_info = {"headers": dict(raw_response.headers)}
#    1176 else:
# -> 1177     response = self.client.create(**payload)
#    1178 return self._create_chat_result(response, generation_info)
#
# File ~/.pyenv/versions/3.10.18/envs/inflearn-llm-application/lib/python3.10/site-packages/openai/_utils/_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.18/envs/inflearn-llm-application/lib/python3.10/site-packages/openai/resources/chat/completions/completions.py:1150, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1104 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1105 def create(
#    1106     self,
#    (...)
#    1147     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1148 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1149     validate_response_format(response_format)
# -> 1150     return self._post(
#    1151         "/chat/completions",
#    1152         body=maybe_transform(
#    1153             {
#    1154                 "messages": messages,
#    1155                 "model": model,
#    1156                 "audio": audio,
#    1157                 "frequency_penalty": frequency_penalty,
#    1158                 "function_call": function_call,
#    1159                 "functions": functions,
#    1160                 "logit_bias": logit_bias,
#    1161                 "logprobs": logprobs,
#    1162                 "max_completion_tokens": max_completion_tokens,
#    1163                 "max_tokens": max_tokens,
#    1164                 "metadata": metadata,
#    1165                 "modalities": modalities,
#    1166                 "n": n,
#    1167                 "parallel_tool_calls": parallel_tool_calls,
#    1168                 "prediction": prediction,
#    1169                 "presence_penalty": presence_penalty,
#    1170                 "prompt_cache_key": prompt_cache_key,
#    1171                 "reasoning_effort": reasoning_effort,
#    1172                 "response_format": response_format,
#    1173                 "safety_identifier": safety_identifier,
#    1174                 "seed": seed,
#    1175                 "service_tier": service_tier,
#    1176                 "stop": stop,
#    1177                 "store": store,
#    1178                 "stream": stream,
#    1179                 "stream_options": stream_options,
#    1180                 "temperature": temperature,
#    1181                 "tool_choice": tool_choice,
#    1182                 "tools": tools,
#    1183                 "top_logprobs": top_logprobs,
#    1184                 "top_p": top_p,
#    1185                 "user": user,
#    1186                 "verbosity": verbosity,
#    1187                 "web_search_options": web_search_options,
#    1188             },
#    1189             completion_create_params.CompletionCreateParamsStreaming
#    1190             if stream
#    1191             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1192         ),
#    1193         options=make_request_options(
#    1194             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1195         ),
#    1196         cast_to=ChatCompletion,
#    1197         stream=stream or False,
#    1198         stream_cls=Stream[ChatCompletionChunk],
#    1199     )
#
# File ~/.pyenv/versions/3.10.18/envs/inflearn-llm-application/lib/python3.10/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)
#    1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.pyenv/versions/3.10.18/envs/inflearn-llm-application/lib/python3.10/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
""
